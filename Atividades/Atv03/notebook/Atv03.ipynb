// %% [markdown]
// # Atv03

// %% [markdown]
// Usando a classe JOptionPane para entrada de dados, receba a nota de duas provas e de um trabalho.

// %%
import javax.swing.JOptionPane;

public class MediaAluno {
    public static void main(String[] args){ 

        String aux; 

    float prova1, prova2, notadotrabalho, media; 

    aux = JOptionPane.showInputDialog("Insira a nota da prova 1: "); 
    prova1 = Float.parseFloat(aux); 

    aux = JOptionPane.showInputDialog("Insira a nota da prova 2: ");
    prova2 = Float.parseFloat(aux);
    
    aux = JOptionPane.showInputDialog("Insira a nota do trabalho: ");
    notadotrabalho = Float.parseFloat(aux);
    
            media= (prova1 + prova2 + notadotrabalho) /3; 
        
            JOptionPane.showMessageDialog(null, "Á media do aluno foi " + media);

    System.exit(0);

    }
}
// Out:
// com.twosigma.beaker.javash.bkrd895dc5a.MediaAluno

// %% [markdown]
// Calcule a média

// %%
media= (prova1 + prova2 + notadotrabalho) /3;
// Out:
// cannot find symbol
//   symbol:   variable media
//   location: class com.twosigma.beaker.javash.bkrd895dc5a.BeakerWrapperClass1261714175Idfb72383a2c7c4986bd8154dd0beebc95
//  media= (prova1 + prova2 + notadotra
//  ^    ^
//
// cannot find symbol
//   symbol:   variable prova1
//   location: class com.twosigma.beaker.javash.bkrd895dc5a.BeakerWrapperClass1261714175Idfb72383a2c7c4986bd8154dd0beebc95
//  media= (prova1 + prova2 + notadotrabalho) /3
//          ^     ^
//
// cannot find symbol
//   symbol:   variable prova2
//   location: class com.twosigma.beaker.javash.bkrd895dc5a.BeakerWrapperClass1261714175Idfb72383a2c7c4986bd8154dd0beebc95
//  media= (prova1 + prova2 + notadotrabalho) /3
//                   ^     ^
//
// cannot find symbol
//   symbol:   variable notadotrabalho
//   location: class com.twosigma.beaker.javash.bkrd895dc5a.BeakerWrapperClass1261714175Idfb72383a2c7c4986bd8154dd0beebc95
//  media= (prova1 + prova2 + notadotrabalho) /3
// ...

// %% [markdown]
// Mostre a média usando o showMessageDialog da classe JOptionPane

// %%
JOptionPane.showMessageDialog(null, "Á media do aluno foi " + media);
// Out:
// cannot find symbol
//   symbol:   variable media
//   location: class com.twosigma.beaker.javash.bkrd895dc5a.BeakerWrapperClass1261714175Id807b1337f5f645758af287f105f4c7d7
// ull, "Á media do aluno foi " + media)
//                                ^    ^
//
// cannot find symbol
//   symbol:   variable JOptionPane
//   location: class com.twosigma.beaker.javash.bkrd895dc5a.BeakerWrapperClass1261714175Id807b1337f5f645758af287f105f4c7d7
//  JOptionPane.showMessageDialog(null, "Á me
//  ^          ^
