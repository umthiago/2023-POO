// %% [markdown]
// # Atv01

// %% [markdown]
// Apresente a soma de todos os argumentos inteiros ou reais recebidos

// %%
import java.util.Scanner;

Scanner LER = new Scanner(System.in);
    
float x = 0f;
float y = 0f;
float result = 0f;

System.out.println("Digite o valor de x");
x = LER.nextFloat();

System.out.println("Digite o valor de y");
y = LER.nextFloat();

result = x + y;

System.out.println("O resultado da soma dos argumentos recebidos é:"+result);
// Out:
// Digite o valor de x
//  56
// Digite o valor de y
//  78
// O resultado da soma dos argumentos recebidos é:134.0
// null
